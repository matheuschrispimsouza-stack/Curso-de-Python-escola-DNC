# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/8_A_Funcao_print()_e_F_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 5

soma = a + b

print(f"soma: {soma}")
print(f"soma: {a + b}")
# Out:
# soma: 15
# soma: 15

# %%
valor_monetario = 1457.8756
print(f"RS {valor_monetario:,.2F}")
# Out:
# RS 1,457.88

# %%
nome = str(input("Digite seu nome: "))
cidade = str(input("Digite sua cidade: "))

print(f"{nome} mora em {cidade}")
# Out:
# Digite seu nome: math
# Digite sua cidade: pern
# math mora em pern
