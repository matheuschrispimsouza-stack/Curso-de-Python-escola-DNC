# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/2_O_que_sao_variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Matheus"
idade = 27
cidade_moro = "Rio de Janeiro"

# Variavel = Valor

# CASE-SENSITIVE = Python diferencia letras maiúsculas de minúsculas,
# então idade e Idade são diferentes.

# %%
print(f"Meu nome é: {nome}")
print(f"Eu moro em: {cidade_moro}")
print(f"Minha idade é: {idade}")
# Out:
# Meu nome é: Matheus
# Eu moro em: Rio de Janeiro
# Minha idade é: 27
