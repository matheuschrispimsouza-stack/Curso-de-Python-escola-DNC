# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/28_Acessando_Elementos_em_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista_variada = [4, 'abacaxi', 12, True]

# %%
lista_variada[0]
# Out:
# 4

# %%
lista_variada[1]
# Out:
# 'abacaxi'

# %%
lista_variada[3]
# Out:
# True

# %%
lista_variada[0] + lista_variada[2]
# Out:
# 16

# %%
lista_variada[-1]
# Out:
# True

# %%
lista_variada[-2]
# Out:
# 12

# %%
lista_variada[-3]
# Out:
# 'abacaxi'

# %%
nova_lista = [5, 3, 29, 1, -2]
if nova_lista[1] % 2 == 0:
  print(nova_lista[1] * nova_lista[2])
else:
  print(nova_lista[3] + nova_lista[4])
# Out:
# -1
