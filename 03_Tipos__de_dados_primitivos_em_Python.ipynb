# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/3_Tipos__de_dados_primitivos_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "bruno"  # Strings
idade = 30  # Números Inteiros
altura = 1.75  # Float
# ponto no lugar da vírgula para números decimais
vai_chover = True
# booleano => Valores lógicos, sendo TRUE (Verdadeiro) ou False (Falso)

# %%
# booleano => Valores lógicos, sendo True (Verdadeiro) ou False (Falso)
vai_chover = True
tenho_guarda_chuva = False

# Lógica: Vou me molhar se vai chover E NOT (não) tenho guarda-chuva
vou_me_molhar = vai_chover and not tenho_guarda_chuva

print(f"Vou me molhar? {vou_me_molhar}")
# Out:
# Vou me molhar? True

# %%
print(vai_chover)
print(tenho_guarda_chuva)
# Out:
# True
# False
