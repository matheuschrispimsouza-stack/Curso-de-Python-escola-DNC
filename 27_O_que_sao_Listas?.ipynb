# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/27_O_que_sao_Listas%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTA => Ordem => []
# Coleção ordenadas que podem armazenar múltiplos valores dentro de uma única variável.
#
#  * Dentro de uma lista, existem os elementos que podem ser de qualquer tipo: números, strings, ou até mesmo outras listas.

# %%
minha_lista = [3, 6 ,9]
print(minha_lista)
# Out:
# [3, 6, 9]

# %%
lista_vazia = []
print(lista_vazia)
# Out:
# []

# %%
lista_variada = [0, 'abacaxi', 4, True]
print(lista_variada)
# Out:
# [0, 'abacaxi', 4, True]
