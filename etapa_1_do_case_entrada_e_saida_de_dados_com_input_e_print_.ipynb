# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/etapa_1_do_case_entrada_e_saida_de_dados_com_input_e_print_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tarefa = input("Digite uma tarefa: ")

print("Tarefa foi adicionada!")

print("Tarefas: ", tarefa)
# Out:
# Digite uma tarefa: ler
# Tarefa foi adicionada!
# Tarefas:  ler
