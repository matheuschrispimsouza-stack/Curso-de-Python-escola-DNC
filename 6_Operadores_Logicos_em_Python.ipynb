# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuschrispimsouza-stack/Curso-de-Python-escola-DNC/blob/main/6_Operadores_Logicos_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tabela verdade

# %% [markdown]
# ![Captura de tela 2026-07-09 214440.png](data:image/png;base64,...)

# %%
vai_chover = False
tenho_guardachuva = True

nao_preciso_de_guardachuva = not vai_chover

print(nao_preciso_de_guardachuva)
# Out:
# True

# %% [markdown]
# # Aluno recebe pontos ?

# %%
aluno_presente = False
fez_trabalho = False

recebe_pontos = aluno_presente or fez_trabalho

print(recebe_pontos)
# Out:
# False

# %% [markdown]
# #Posso entrar no cássino ?

# %%
idade = 19
aceite_termos = True

pode_jogar = idade >= 18 and aceite_termos

print(f"Pode jogar ? {pode_jogar}")
# Out:
# Pode jogar ? True
